# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img=cv2.imread('./test/APJ.jpeg')
img.shape
# Out:
# (395, 474, 3)

# %%
 plt.imshow(img)

# %%
gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray
# Out:
# array([[73, 72, 71, ..., 29, 27, 27],
#        [73, 72, 70, ..., 30, 26, 27],
#        [73, 72, 70, ..., 32, 26, 26],
#        ...,
#        [48, 36, 42, ..., 38, 34, 46],
#        [66, 48, 48, ..., 38, 41, 66],
#        [79, 55, 49, ..., 38, 32, 68]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[197,  87, 112, 112]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (197, 87, 112, 112)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test/APJ.jpeg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test/APJ.jpeg')
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread('./test/APJ2.jpeg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test/APJ2.jpeg')
cropped_image_no_2_eyes

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/APJ abdul kalam',
#  './dataset/CV Raman',
#  './dataset/Homie Jahanghir Bhabha',
#  './dataset/Ramanujan',
#  './dataset/Vikram Sarabhai']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
scientist_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    scientist_name = img_dir.split('/')[-1]
    print(scientist_name)
    
    scientist_file_names_dict[scientist_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + scientist_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = scientist_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            scientist_file_names_dict[scientist_name].append(cropped_file_path)
            count +=  1
# Out:
# APJ abdul kalam
# Generating cropped images in folder:  ./dataset/cropped/APJ abdul kalam
# CV Raman
# Generating cropped images in folder:  ./dataset/cropped/CV Raman
# Homie Jahanghir Bhabha
# Generating cropped images in folder:  ./dataset/cropped/Homie Jahanghir Bhabha
# Ramanujan
# Generating cropped images in folder:  ./dataset/cropped/Ramanujan
# Vikram Sarabhai
# Generating cropped images in folder:  ./dataset/cropped/Vikram Sarabhai

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_image,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
scientist_file_names_dict = {}
for img_dir in cropped_image_dirs:
    scientist_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    scientist_file_names_dict[scientist_name] = file_list
scientist_file_names_dict
# Out:
# {'APJ abdul kalam': ['./dataset/cropped/APJ abdul kalam\\APJ abdul kalam1.png',
#   './dataset/cropped/APJ abdul kalam\\APJ abdul kalam10.png',
#   './dataset/cropped/APJ abdul kalam\\APJ abdul kalam11.png',
#   './dataset/cropped/APJ abdul kalam\\APJ abdul kalam12.png',
#   './dataset/cropped/APJ abdul kalam\\APJ abdul kalam13.png',
#   './dataset/cropped/APJ abdul kalam\\APJ abdul kalam14.png',
#   './dataset/cropped/APJ abdul kalam\\APJ abdul kalam15.png',
#   './dataset/cropped/APJ abdul kalam\\APJ abdul kalam16.png',
#   './dataset/cropped/APJ abdul kalam\\APJ abdul kalam17.png',
#   './dataset/cropped/APJ abdul kalam\\APJ abdul kalam18.png',
#   './dataset/cropped/APJ abdul kalam\\APJ abdul kalam19.png',
#   './dataset/cropped/APJ abdul kalam\\APJ abdul kalam2.png',
#   './dataset/cropped/APJ abdul kalam\\APJ abdul kalam20.png',
#   './dataset/cropped/APJ abdul kalam\\APJ abdul kalam3.png',
#   './dataset/cropped/APJ abdul kalam\\APJ abdul kalam4.png',
#   './dataset/cropped/APJ abdul kalam\\APJ abdul kalam5.png',
#   './dataset/cropped/APJ abdul kalam\\APJ abdul kalam6.png',
#   './dataset/cropped/APJ abdul kalam\\APJ abdul kalam7.png',
#   './dataset/cropped/APJ abdul kalam\\APJ abdul kalam8.png',
#   './dataset/cropped/APJ abdul kalam\\APJ abdul kalam9.png'],
#  'CV Raman': ['./dataset/cropped/CV Raman\\CV Raman1.png',
#   './dataset/cropped/CV Raman\\CV Raman10.png',
#   './dataset/cropped/CV Raman\\CV Raman11.png',
#   './dataset/cropped/CV Raman\\CV Raman12.png',
#   './dataset/cropped/CV Raman\\CV Raman13.png',
#   './dataset/cropped/CV Raman\\CV Raman14.png',
#   './dataset/cropped/CV Raman\\CV Raman15.png',
#   './dataset/cropped/CV Raman\\CV Raman16.png',
#   './dataset/cropped/CV Raman\\CV Raman17.png',
#   './dataset/cropped/CV Raman\\CV Raman18.png',
#   './dataset/cropped/CV Raman\\CV Raman19.png',
#   './dataset/cropped/CV Raman\\CV Raman2.png',
#   './dataset/cropped/CV Raman\\CV Raman20.png',
#   './dataset/cropped/CV Raman\\CV Raman21.png',
#   './dataset/cropped/CV Raman\\CV Raman22.png',
#   './dataset/cropped/CV Raman\\CV Raman23.png',
#   './dataset/cropped/CV Raman\\CV Raman24.png',
#   './dataset/cropped/CV Raman\\CV Raman25.png',
#   './dataset/cropped/CV Raman\\CV Raman26.png',
#   './dataset/cropped/CV Raman\\CV Raman27.png',
#   './dataset/cropped/CV Raman\\CV Raman28.png',
#   './dataset/cropped/CV Raman\\CV Raman29.png',
#   './dataset/cropped/CV Raman\\CV Raman3.png',
#   './dataset/cropped/CV Raman\\CV Raman30.png',
#   './dataset/cropped/CV Raman\\CV Raman31.png',
#   './dataset/cropped/CV Raman\\CV Raman32.png',
#   './dataset/cropped/CV Raman\\CV Raman33.png',
#   './dataset/cropped/CV Raman\\CV Raman34.png',
#   './dataset/cropped/CV Raman\\CV Raman35.png',
#   './dataset/cropped/CV Raman\\CV Raman36.png',
#   './dataset/cropped/CV Raman\\CV Raman37.png',
#   './dataset/cropped/CV Raman\\CV Raman38.png',
#   './dataset/cropped/CV Raman\\CV Raman39.png',
#   './dataset/cropped/CV Raman\\CV Raman4.png',
#   './dataset/cropped/CV Raman\\CV Raman40.png',
#   './dataset/cropped/CV Raman\\CV Raman41.png',
#   './dataset/cropped/CV Raman\\CV Raman42.png',
#   './dataset/cropped/CV Raman\\CV Raman43.png',
#   './dataset/cropped/CV Raman\\CV Raman44.png',
#   './dataset/cropped/CV Raman\\CV Raman45.png',
#   './dataset/cropped/CV Raman\\CV Raman46.png',
#   './dataset/cropped/CV Raman\\CV Raman47.png',
#   './dataset/cropped/CV Raman\\CV Raman48.png',
#   './dataset/cropped/CV Raman\\CV Raman49.png',
#   './dataset/cropped/CV Raman\\CV Raman5.png',
#   './dataset/cropped/CV Raman\\CV Raman50.png',
#   './dataset/cropped/CV Raman\\CV Raman51.png',
#   './dataset/cropped/CV Raman\\CV Raman52.png',
#   './dataset/cropped/CV Raman\\CV Raman53.png',
#   './dataset/cropped/CV Raman\\CV Raman54.png',
#   './dataset/cropped/CV Raman\\CV Raman55.png',
#   './dataset/cropped/CV Raman\\CV Raman56.png',
#   './dataset/cropped/CV Raman\\CV Raman57.png',
#   './dataset/cropped/CV Raman\\CV Raman58.png',
#   './dataset/cropped/CV Raman\\CV Raman59.png',
#   './dataset/cropped/CV Raman\\CV Raman6.png',
#   './dataset/cropped/CV Raman\\CV Raman60.png',
#   './dataset/cropped/CV Raman\\CV Raman61.png',
#   './dataset/cropped/CV Raman\\CV Raman62.png',
#   './dataset/cropped/CV Raman\\CV Raman63.png',
#   './dataset/cropped/CV Raman\\CV Raman64.png',
#   './dataset/cropped/CV Raman\\CV Raman65.png',
#   './dataset/cropped/CV Raman\\CV Raman66.png',
#   './dataset/cropped/CV Raman\\CV Raman67.png',
#   './dataset/cropped/CV Raman\\CV Raman7.png',
#   './dataset/cropped/CV Raman\\CV Raman8.png',
#   './dataset/cropped/CV Raman\\CV Raman9.png'],
#  'Homie Jahanghir Bhabha': ['./dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha1.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha10.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha11.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha12.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha13.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha14.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha15.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha16.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha17.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha18.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha19.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha2.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha20.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha21.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha22.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha23.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha24.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha25.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha26.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha27.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha28.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha29.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha3.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha30.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha31.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha32.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha33.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha34.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha35.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha36.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha37.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha38.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha39.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha4.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha40.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha41.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha5.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha6.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha7.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha8.png',
#   './dataset/cropped/Homie Jahanghir Bhabha\\Homie Jahanghir Bhabha9.png'],
#  'Ramanujan': ['./dataset/cropped/Ramanujan\\Ramanujan1.png',
#   './dataset/cropped/Ramanujan\\Ramanujan10.png',
#   './dataset/cropped/Ramanujan\\Ramanujan100.png',
#   './dataset/cropped/Ramanujan\\Ramanujan101.png',
#   './dataset/cropped/Ramanujan\\Ramanujan11.png',
#   './dataset/cropped/Ramanujan\\Ramanujan12.png',
#   './dataset/cropped/Ramanujan\\Ramanujan13.png',
#   './dataset/cropped/Ramanujan\\Ramanujan14.png',
#   './dataset/cropped/Ramanujan\\Ramanujan15.png',
#   './dataset/cropped/Ramanujan\\Ramanujan16.png',
#   './dataset/cropped/Ramanujan\\Ramanujan17.png',
#   './dataset/cropped/Ramanujan\\Ramanujan18.png',
#   './dataset/cropped/Ramanujan\\Ramanujan19.png',
#   './dataset/cropped/Ramanujan\\Ramanujan2.png',
#   './dataset/cropped/Ramanujan\\Ramanujan20.png',
#   './dataset/cropped/Ramanujan\\Ramanujan21.png',
#   './dataset/cropped/Ramanujan\\Ramanujan22.png',
#   './dataset/cropped/Ramanujan\\Ramanujan23.png',
#   './dataset/cropped/Ramanujan\\Ramanujan24.png',
#   './dataset/cropped/Ramanujan\\Ramanujan25.png',
#   './dataset/cropped/Ramanujan\\Ramanujan26.png',
#   './dataset/cropped/Ramanujan\\Ramanujan27.png',
#   './dataset/cropped/Ramanujan\\Ramanujan28.png',
#   './dataset/cropped/Ramanujan\\Ramanujan29.png',
#   './dataset/cropped/Ramanujan\\Ramanujan3.png',
#   './dataset/cropped/Ramanujan\\Ramanujan30.png',
#   './dataset/cropped/Ramanujan\\Ramanujan31.png',
#   './dataset/cropped/Ramanujan\\Ramanujan32.png',
#   './dataset/cropped/Ramanujan\\Ramanujan33.png',
#   './dataset/cropped/Ramanujan\\Ramanujan34.png',
#   './dataset/cropped/Ramanujan\\Ramanujan35.png',
#   './dataset/cropped/Ramanujan\\Ramanujan36.png',
#   './dataset/cropped/Ramanujan\\Ramanujan37.png',
#   './dataset/cropped/Ramanujan\\Ramanujan38.png',
#   './dataset/cropped/Ramanujan\\Ramanujan39.png',
#   './dataset/cropped/Ramanujan\\Ramanujan4.png',
#   './dataset/cropped/Ramanujan\\Ramanujan40.png',
#   './dataset/cropped/Ramanujan\\Ramanujan41.png',
#   './dataset/cropped/Ramanujan\\Ramanujan42.png',
#   './dataset/cropped/Ramanujan\\Ramanujan43.png',
#   './dataset/cropped/Ramanujan\\Ramanujan44.png',
#   './dataset/cropped/Ramanujan\\Ramanujan45.png',
#   './dataset/cropped/Ramanujan\\Ramanujan46.png',
#   './dataset/cropped/Ramanujan\\Ramanujan47.png',
#   './dataset/cropped/Ramanujan\\Ramanujan48.png',
#   './dataset/cropped/Ramanujan\\Ramanujan49.png',
#   './dataset/cropped/Ramanujan\\Ramanujan5.png',
#   './dataset/cropped/Ramanujan\\Ramanujan50.png',
#   './dataset/cropped/Ramanujan\\Ramanujan51.png',
#   './dataset/cropped/Ramanujan\\Ramanujan52.png',
#   './dataset/cropped/Ramanujan\\Ramanujan53.png',
#   './dataset/cropped/Ramanujan\\Ramanujan54.png',
#   './dataset/cropped/Ramanujan\\Ramanujan55.png',
#   './dataset/cropped/Ramanujan\\Ramanujan56.png',
#   './dataset/cropped/Ramanujan\\Ramanujan57.png',
#   './dataset/cropped/Ramanujan\\Ramanujan58.png',
#   './dataset/cropped/Ramanujan\\Ramanujan59.png',
#   './dataset/cropped/Ramanujan\\Ramanujan6.png',
#   './dataset/cropped/Ramanujan\\Ramanujan60.png',
#   './dataset/cropped/Ramanujan\\Ramanujan61.png',
#   './dataset/cropped/Ramanujan\\Ramanujan62.png',
#   './dataset/cropped/Ramanujan\\Ramanujan63.png',
#   './dataset/cropped/Ramanujan\\Ramanujan64.png',
#   './dataset/cropped/Ramanujan\\Ramanujan65.png',
#   './dataset/cropped/Ramanujan\\Ramanujan66.png',
#   './dataset/cropped/Ramanujan\\Ramanujan67.png',
#   './dataset/cropped/Ramanujan\\Ramanujan68.png',
#   './dataset/cropped/Ramanujan\\Ramanujan69.png',
#   './dataset/cropped/Ramanujan\\Ramanujan7.png',
#   './dataset/cropped/Ramanujan\\Ramanujan70.png',
#   './dataset/cropped/Ramanujan\\Ramanujan71.png',
#   './dataset/cropped/Ramanujan\\Ramanujan72.png',
#   './dataset/cropped/Ramanujan\\Ramanujan73.png',
#   './dataset/cropped/Ramanujan\\Ramanujan74.png',
#   './dataset/cropped/Ramanujan\\Ramanujan75.png',
#   './dataset/cropped/Ramanujan\\Ramanujan76.png',
#   './dataset/cropped/Ramanujan\\Ramanujan77.png',
#   './dataset/cropped/Ramanujan\\Ramanujan78.png',
#   './dataset/cropped/Ramanujan\\Ramanujan79.png',
#   './dataset/cropped/Ramanujan\\Ramanujan8.png',
#   './dataset/cropped/Ramanujan\\Ramanujan80.png',
#   './dataset/cropped/Ramanujan\\Ramanujan81.png',
#   './dataset/cropped/Ramanujan\\Ramanujan82.png',
#   './dataset/cropped/Ramanujan\\Ramanujan83.png',
#   './dataset/cropped/Ramanujan\\Ramanujan84.png',
#   './dataset/cropped/Ramanujan\\Ramanujan85.png',
#   './dataset/cropped/Ramanujan\\Ramanujan86.png',
#   './dataset/cropped/Ramanujan\\Ramanujan87.png',
#   './dataset/cropped/Ramanujan\\Ramanujan88.png',
#   './dataset/cropped/Ramanujan\\Ramanujan89.png',
#   './dataset/cropped/Ramanujan\\Ramanujan9.png',
#   './dataset/cropped/Ramanujan\\Ramanujan90.png',
#   './dataset/cropped/Ramanujan\\Ramanujan91.png',
#   './dataset/cropped/Ramanujan\\Ramanujan92.png',
#   './dataset/cropped/Ramanujan\\Ramanujan93.png',
#   './dataset/cropped/Ramanujan\\Ramanujan94.png',
#   './dataset/cropped/Ramanujan\\Ramanujan95.png',
#   './dataset/cropped/Ramanujan\\Ramanujan96.png',
#   './dataset/cropped/Ramanujan\\Ramanujan97.png',
#   './dataset/cropped/Ramanujan\\Ramanujan98.png',
#   './dataset/cropped/Ramanujan\\Ramanujan99.png'],
#  'Vikram Sarabhai': ['./dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai1.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai10.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai11.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai12.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai13.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai14.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai15.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai16.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai17.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai18.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai19.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai2.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai20.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai21.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai22.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai23.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai24.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai25.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai26.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai27.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai28.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai29.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai3.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai30.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai31.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai32.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai33.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai34.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai35.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai36.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai37.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai38.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai39.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai4.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai40.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai41.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai42.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai43.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai44.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai45.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai46.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai47.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai48.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai49.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai5.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai50.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai51.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai52.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai53.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai54.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai55.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai56.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai57.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai58.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai59.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai6.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai60.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai61.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai62.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai63.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai64.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai65.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai66.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai67.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai68.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai69.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai7.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai70.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai71.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai72.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai73.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai74.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai75.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai76.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai77.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai78.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai79.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai8.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai80.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai81.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai82.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai83.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai84.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai85.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai86.png',
#   './dataset/cropped/Vikram Sarabhai\\Vikram Sarabhai9.png']}

# %%
class_dict = {}
count = 0
for scientist_name in scientist_file_names_dict.keys():
    class_dict[scientist_name] = count
    count = count + 1
class_dict
# Out:
# {'APJ abdul kalam': 0,
#  'CV Raman': 1,
#  'Homie Jahanghir Bhabha': 2,
#  'Ramanujan': 3,
#  'Vikram Sarabhai': 4}

# %%
X, y = [], []
for scientist_name, training_files in scientist_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[scientist_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[160],
#        [147],
#        [145],
#        ...,
#        [219],
#        [218],
#        [216]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (315, 4096)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.8607594936708861

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73         6
#            1       0.88      0.82      0.85        17
#            2       0.85      1.00      0.92        11
#            3       0.92      0.88      0.90        25
#            4       0.81      0.85      0.83        20
#
#     accuracy                           0.86        79
#    macro avg       0.85      0.84      0.84        79
# weighted avg       0.86      0.86      0.86        79

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
# Out:
#                  model  best_score  \
# 0                  svm    0.932358
# 1        random_forest    0.843262
# 2  logistic_regression    0.898670
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.932358
# 1        random_forest    0.809220
# 2  logistic_regression    0.898670
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.8734177215189873

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.7721518987341772

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8607594936708861

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 4,  1,  0,  0,  1],
#        [ 1, 16,  0,  0,  0],
#        [ 0,  0, 11,  0,  0],
#        [ 1,  0,  0, 22,  2],
#        [ 0,  0,  3,  1, 16]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'APJ abdul kalam': 0,
#  'CV Raman': 1,
#  'Homie Jahanghir Bhabha': 2,
#  'Ramanujan': 3,
#  'Vikram Sarabhai': 4}

# %%
#Saving the trained model
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (1.1.0)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
